# %%
# Viz mantra
from matplotlib import pyplot as plt
# %matplotlib inline
# %config Inlinebackend.figure_format = 'retina'

import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

# %%
from scipy.stats import uniform
from scipy.stats import norm
from scipy.stats import expon

import numpy as np
import pandas as pd

# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.20011666 2.10981357 2.07845568 2.33549886 2.38752727 2.13902643
#  2.49233422 2.8630624  2.77102698 2.25208122]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def unif_random_numbers(bottom, ceiling, count):
    x = uniform.rvs(size=count)
    return [bottom + (ceiling-bottom) * i for i in x]

# %%
random1 = unif_random_numbers(10,15,100)
random2 = unif_random_numbers(10,60,1000)

# %%
sns.histplot(random1, palette="Blues", bins=10)
plt.ylim(0, 100);
# Out:
# C:\Users\lucia\AppData\Local\Temp\ipykernel_13936\3506726681.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(random1, palette="Blues", bins=10)

# %%
sns.histplot(random2, palette="Blues", bins=10);
# Out:
# C:\Users\lucia\AppData\Local\Temp\ipykernel_13936\3859192922.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(random2, palette="Blues", bins=10);

# %% [markdown]
# How are the two distributions different?

# %%
# For both of the distributions there is almost the same amount of numbers in each bin

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
def norm_random_numbers(mean, stdev, count):
    return norm(mean, stdev).rvs(size=count)

# %%
norm1 = norm_random_numbers(10,1,1000)
sns.histplot(norm1, palette="Blues",bins=50);
# Out:
# C:\Users\lucia\AppData\Local\Temp\ipykernel_13936\254734549.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(norm1, palette="Blues",bins=50);

# %%
norm2 = norm_random_numbers(10,50,1000)
sns.histplot(norm2, palette="Blues",bins=50);
# Out:
# C:\Users\lucia\AppData\Local\Temp\ipykernel_13936\3995911710.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(norm2, palette="Blues",bins=50);

# %% [markdown]
# How are the two distributions different?

# %%
# When the standard deviation is lower, the numbers will be more 'near' to one another
# so their range will be more narrow

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
df = pd.read_csv("vehicles.csv")
df.sample(5)
# Out:
#           Make       Model  Year  Engine Displacement  Cylinders  \
# 26910   Nissan      Sentra  2010                  2.0        4.0
# 14139     Ford  Taurus FWD  2014                  2.0        4.0
# 813       Audi  A4 quattro  2004                  3.0        6.0
# 3211   Bugatti      Veyron  2015                  8.0       16.0
# 13508     Ford       Laser  1988                  1.6        4.0
#
#           Transmission                  Drivetrain Vehicle Class Fuel Type  \
# 26910     Manual 6-spd           Front-Wheel Drive  Midsize Cars   Regular
# 14139   Automatic (S6)           Front-Wheel Drive    Large Cars   Regular
# 813     Automatic (S5)  4-Wheel or All-Wheel Drive  Compact Cars   Premium
# 3211       Auto(AM-S7)             All-Wheel Drive   Two Seaters   Premium
# 13508  Automatic 4-spd           Front-Wheel Drive  Compact Cars   Regular
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
df["Fuel Barrels/Year"].mean()
# Out:
# 17.609055502328133

# %%
df["Fuel Barrels/Year"].median()
# Out:
# 17.347894736842107

# %%
sns.histplot(x=df["Fuel Barrels/Year"], bins=40);

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
sns.histplot(x=df["CO2 Emission Grams/Mile"], bins=40);

# %%
df["CO2 Emission Grams/Mile"].mean()
# Out:
# 475.3163392572124

# %%
df["CO2 Emission Grams/Mile"].median()
# Out:
# 467.7368421052632

# %% [markdown]
# 3. Combined MPG

# %%
sns.histplot(x=df["Combined MPG"], bins=50);

# %%
df["Combined MPG"].mean()
# Out:
# 19.92932242990654

# %%
df["Combined MPG"].median()
# Out:
# 19.0

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# Fuel Barrels/Year and Combined MPG because mean and median are more near to each other

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def exp_random_numbers(mean,size):
    return np.random.exponential(mean,size)

# %%
seq1 = exp_random_numbers(2,1000)
seq2 = exp_random_numbers(200,1000)

# %%
sns.histplot(seq1, bins=100);

# %%
sns.histplot(seq2, bins=100);

# %% [markdown]
# How are the two distributions different?

# %%
# If the mean is higher the range of number will be wider

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
time_bank = expon(scale=10)
p_less_15 = time_bank.cdf(15)
p_less_15
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
p_more_15 = 1- p_less_15
p_more_15
# Out:
# 0.2231301601484298
