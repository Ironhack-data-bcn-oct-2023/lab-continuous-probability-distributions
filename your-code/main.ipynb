# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
import numpy as np 
import random
from matplotlib import pyplot as plt
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.31788975 2.65406817 2.85160508 2.5270785  2.40083184 2.88242396
#  2.75126718 2.09366884 2.10972861 2.76738512]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def uniform_distribution(bottom,ceiling,count):
    return np.random.uniform(bottom, ceiling, count)

# %%
fig, ax = plt.subplots(1,2, sharey= True)
plt.figure(figsize=(20,15))
array_ = uniform_distribution(bottom=10, ceiling=15, count=100);
ax[0].set_xticks(np.arange(10,16,1));
ax[0].hist(array_, bins=20);

array_1 = uniform_distribution(bottom=10, ceiling=60, count=1000);
ax[1].hist(array_1, bins=20);
ax[1].set_xticks(np.arange(10, 70, 10));

# %% [markdown]
# How are the two distributions different?

# %%
'''
The x-axis from the left plot goes from 10 to 15, 
whereas in the right plot goes from 10 to 60, so it has a larger x-axis. 
Regarding y, the distribution from the left plot is similar, variates between 0 and 10. 
In the right plot, this variation is bigger as it can go from 40 to 70.
'''

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm
import seaborn as sns
def normal_distribution(average, st_dev,size=1000):
    return np.random.normal(average, st_dev, size)

# %%
fig, ax = plt.subplots(1, 2, sharey=True, figsize=(10, 6))


data = normal_distribution(10, 1)
ax[0].hist(data, bins=50)
ax[0].set_title("Random Samples from a Normal Distribution")
ax[0].set_xlabel("Values")

data1 = normal_distribution(10, 50)
ax[1].hist(data1,bins=50)
ax[1].set_title("Random Samples from a Normal Distribution")
ax[1].set_xlabel("Values")

plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
'''
clsdhvio
'''

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
import pandas as pd
vehicles = pd.read_csv("C:/Users/Sara/lectures/datasets/vehicles.csv")
vehicles.sample(10)
# Out:
#               Make                    Model  Year  Engine Displacement  \
# 22082         MINI  Cooper S Hardtop 2 door  2016                  2.0
# 28239      Pontiac                     6000  1988                  2.5
# 9445         Dodge                     Colt  1985                  1.5
# 28006     Plymouth                  Reliant  1985                  2.2
# 20981  Lamborghini      Murcielago Roadster  2009                  6.5
# 81           Acura                  Integra  1998                  1.8
# 10117        Dodge              Durango AWD  2015                  5.7
# 30920        Scion                       xB  2009                  2.4
# 6878     Chevrolet           S10 Pickup 2WD  1996                  2.2
# 18248      Hyundai           Sonata Limited  2016                  2.0
#
#        Cylinders     Transmission                  Drivetrain  \
# 22082        4.0     Manual 6-spd           Front-Wheel Drive
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
sns.histplot(data = vehicles,x="Fuel Barrels/Year",bins=50, color = "royalblue");
plt.axvline(vehicles["Fuel Barrels/Year"].mean(), color= "red");

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
sns.histplot(data = vehicles,x="CO2 Emission Grams/Mile",bins=50, color="royalblue");
plt.axvline(vehicles["CO2 Emission Grams/Mile"].mean(), color= "red");

# %% [markdown]
# 3. Combined MPG

# %%
sns.histplot(data = vehicles,x="Combined MPG",bins=50, color = "royalblue");
plt.axvline(vehicles["Combined MPG"].mean(), color= "red")

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
''' 
All are normally distributed, because the mean is always 
in the center of the distribution. 
'''

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def exp_distributed(mean, count):
    return np.random.exponential(mean, count)

fig, ax = plt.subplots(1, 2, sharey=True)
arr1 = exp_distributed(2, 1000)
ax[0].hist(arr1, bins=100)
ax[0].set_xticks(np.arange(0, max(arr1), 2))
ax[0].axvline(arr1.mean(), color= "red")

arr2 = exp_distributed(200, 1000)
ax[1].hist(arr2, bins=100)
ax[1].set_xticks(np.arange(0, max(arr2), 300))
ax[1].axvline(arr2.mean(), color= "red")
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
''' 
The main difference is in the x-axis.
'''

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# Hint: This is same as saying P(x<15)
from scipy.stats import expon
lambda_param = 1 / 10

# Time threshold (less than fifteen minutes)
time_threshold = 15

# Calculate the probability using the cumulative distribution function (CDF)
probability_less_than_15_minutes = expon.cdf(time_threshold, scale=1/lambda_param)

probability_less_than_15_minutes
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
more_than_15 = 1-probability_less_than_15_minutes
more_than_15
# Out:
# 0.2231301601484298
