# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
# Viz mantra
from matplotlib import pyplot as plt
# %matplotlib inline
# %config Inlinebackend.figure_format = 'retina'

import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

import pylab as p
import numpy as np
import pandas as pd

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.05350059 2.23101503 2.09473189 2.40691566 2.41187553 2.23391037
#  2.26006477 2.87347716 2.5154752  2.40378836]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def rand_numbers(bottom, ceiling, count):
    my_uniform = uniform(bottom, ceiling) 
    return my_uniform.rvs(count)

# %%
p1 = rand_numbers(10, 15, 100)

# %%
p2 = rand_numbers(10, 60, 1000)

# %%
import seaborn as sns
sns.histplot(p1, palette="Blues");
# Out:
# /var/folders/_b/4s7pp99j1qq9lxsqpjphc78m0000gn/T/ipykernel_16371/1307090763.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(p1, palette="Blues");

# %%
sns.histplot(p2, palette="Blues");
# Out:
# /var/folders/_b/4s7pp99j1qq9lxsqpjphc78m0000gn/T/ipykernel_16371/1880818204.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(p2, palette="Blues");

# %% [markdown]
# How are the two distributions different?

# %%
# the higher the count, more uniform the values of the arrays are.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

def normal_randoms(avg, std, count):
    result = norm(avg, std)
    sample = result.rvs(count)
    return sample

# %%
# Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1

n1 = normal_randoms(10, 1, 1000)

# %%
# Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50

n2 = normal_randoms(10, 50, 1000)

# %%
sns.histplot(n1, palette="Blues");
# Out:
# /var/folders/_b/4s7pp99j1qq9lxsqpjphc78m0000gn/T/ipykernel_16371/3629700630.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(n1, palette="Blues");

# %%
sns.histplot(n2, palette="Blues");
# Out:
# /var/folders/_b/4s7pp99j1qq9lxsqpjphc78m0000gn/T/ipykernel_16371/1129730589.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(n2, palette="Blues");

# %% [markdown]
# How are the two distributions different?

# %%
# In the second plot you can see that there are a lot more numbers far away from the mean.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
vehicles = pd.read_csv('vehicles.csv')
fuel = pd.DataFrame(vehicles['Fuel Barrels/Year'])
fuel.describe()
# Out:
#        Fuel Barrels/Year
# count       35952.000000
# mean           17.609056
# std             4.467283
# min             0.060000
# 25%            14.699423
# 50%            17.347895
# 75%            20.600625
# max            47.087143

# %%
avg1 = vehicles['Fuel Barrels/Year'].mean()
std1 = vehicles['Fuel Barrels/Year'].std()
count1 = len(vehicles['Fuel Barrels/Year'])

plot1 = normal_randoms(avg1, std1, count1)

sns.histplot(plot1);

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
avg2 = vehicles['CO2 Emission Grams/Mile'].mean()
std2 = vehicles['CO2 Emission Grams/Mile'].std()
count2 = len(vehicles['CO2 Emission Grams/Mile'])

plot2 = normal_randoms(avg1, std1, count1)

sns.histplot(plot2, color='red')
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
avg3 = vehicles['Combined MPG'].mean()
std3 = vehicles['Combined MPG'].std()
count3 = len(vehicles['Combined MPG'])

plot3 = normal_randoms(avg1, std1, count1)

sns.histplot(plot3, color='green')
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# All of them seem equally normally distributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
from scipy.stats import expon
def exponential_numb(mean, count):
    return np.random.exponential(mean, count)

# %%
e1 = exponential_numb(2, 1000)
sns.histplot(e1, color='yellow')
plt.axvline(2, color="red")
plt.show();

# %%
e2 = exponential_numb(200, 1000)
sns.histplot(e2, color='orange')
plt.axvline(200, color="blue")
plt.show();

# %% [markdown]
# How are the two distributions different?

# %%
# A higher mean leads to a more spread out distribution.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)

# %%
# scale = 10 #min
bank = expon(scale=10)
prob_less_fifteen = bank.cdf(14)
prob_less_fifteen
# Out:
# 0.7534030360583935

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
prob_more_15 = 1 - prob_less_fifteen
prob_more_15
# Out:
# 0.24659696394160646
