# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import uniform, norm, expon, skew
import pandas as pd
import numpy as np

x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.43910754 2.74730622 2.68948771 2.01513703 2.02675443 2.38242322
#  2.49180955 2.22616457 2.08184177 2.34197897]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def ramndomly_distributed_numbers(bottom, ceiling, count):
  x = uniform.rvs(size=count)
  randoms  = bottom + (ceiling-bottom)*x
  return randoms

# %%
sns.histplot(ramndomly_distributed_numbers(10, 15, 100));
# Out:
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(ramndomly_distributed_numbers(10, 60, 1000));
# Out:
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# How are the two distributions different?

# %%
# all the numbers in the sample have the same probability so the bigger the sample the more flattened will be the count

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
def normally_distributed_numbers(avg, stdev, count):
  x = norm(avg, stdev)
  randoms  = x.rvs(count)
  return randoms

# %%
sns.histplot(normally_distributed_numbers(10, 1, 1000), color="khaki");
# Out:
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(normally_distributed_numbers(10, 50, 1000), color="lightcoral");
# Out:
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# How are the two distributions different?

# %%
# in the first one the base is narrower because there is less deviation, on the other hand the second plot has a wider base and a smaller max point

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
vehicles = pd.read_csv("./vehicles.csv")

shapiro_test = stats.shapiro(vehicles['Fuel Barrels/Year'])
print(f"Shapiro-Wilk test statistic: {shapiro_test[0]}, p-value: {shapiro_test[1]}")

sns.histplot(vehicles['Fuel Barrels/Year'], bins=20, kde=True, color='skyblue')
plt.axvline(vehicles['Fuel Barrels/Year'].mean(), color='red', lw=2, label='Mean')
plt.axvline(vehicles['Fuel Barrels/Year'].median(), color='green', ls='--', lw=2, label='Median')
plt.title('Histogram of Fuel Barrels/Year')
plt.xlabel('Fuel Barrels/Year')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Shapiro-Wilk test statistic: 0.967258095741272, p-value: 0.0

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
sns.histplot(vehicles['CO2 Emission Grams/Mile'], bins=20, kde=True, color='darkseagreen')
plt.axvline(vehicles['CO2 Emission Grams/Mile'].mean(), color='red', lw=2, label='Mean')
plt.axvline(vehicles['CO2 Emission Grams/Mile'].median(), color='green', ls='--', lw=2, label='Median')
plt.title('Histogram of CO2 Emission Grams/Mile')
plt.xlabel('CO2 Emission Grams/Mile')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# 3. Combined MPG

# %%
sns.histplot(vehicles['Combined MPG'], bins=20, kde=True, color='mediumpurple')
plt.axvline(vehicles['Combined MPG'].mean(), color='red', lw=2, label='Mean')
plt.axvline(vehicles['Combined MPG'].median(), color='green', ls='--', lw=2, label='Median')
plt.title('Histogram of Combined MPG')
plt.xlabel('Combined MPG')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
print("Skewness of the diferent histograms")
print("Fuel Barrels/Year: ", skew(vehicles["Fuel Barrels/Year"]))
print("CO2 Emission Grams/Mile: ", skew(vehicles["CO2 Emission Grams/Mile"]))
print("Combined MPG: ", skew(vehicles["Combined MPG"]))

# Fuel Barrels/Year has the skwness more close to 0 than the others so it is the more normally distributed
# Out:
# Skewness of the diferent histograms
# Fuel Barrels/Year:  0.6382445784906976
# CO2 Emission Grams/Mile:  0.7416608937445333
# Combined MPG:  1.0677281511016457

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def random_exponential_distribution(mean, size):
  return np.random.exponential(mean, size)

# %%
sns.histplot(random_exponential_distribution(20, 1000), bins=100, kde=False, color='mediumpurple')
plt.title('Histogram of Combined MPG')
plt.xlabel('Combined MPG')
plt.ylabel('Frequency')
plt.show()
# Out:
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(random_exponential_distribution(200, 1000), bins=100, kde=False, color='khaki')
plt.title('Histogram of Combined MPG')
plt.xlabel('Combined MPG')
plt.ylabel('Frequency')
plt.show()
# Out:
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\oriol\miniconda3\envs\ironhack\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# How are the two distributions different?

# %%
# If the mean is bigger like in the second plot the range of values will be bigger and the curve would be more pronunced if both are compared

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
scale = 10
time_limit = 15

less_than_15 = expon.cdf(time_limit, scale=scale)
less_than_15
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
1 - less_than_15
# Out:
# 0.2231301601484298
