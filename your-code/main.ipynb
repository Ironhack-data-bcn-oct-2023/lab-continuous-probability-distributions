# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %%
from scipy.stats import norm
from scipy.stats import expon
import seaborn as sns
import pandas as pd

# Viz mantra
from matplotlib import pyplot as plt
# %matplotlib inline
# %config Inlinebackend.figure_format = 'retina'

import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.10292903 2.19408944 2.86730311 2.37899757 2.62939953 2.79941624
#  2.90317044 2.56993171 2.53605877 2.66689101]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def random_numbers (bottom, ceiling, count):
    my_uniform = uniform(bottom, ceiling) 
    random =  my_uniform.rvs(count)
    return random
     
def random_numbers_plot (bottom, ceiling, count):
    my_uniform = uniform(bottom, ceiling) 
    random =  my_uniform.rvs(count)
    return sns.histplot(random, palette="Blues");
     

random_numbers( 10,15,100)
# Out:
# array([23.19710109, 14.41807306, 12.82669402, 11.09375172, 12.37170316,
#        15.42570901, 12.0055914 , 10.83157969, 20.88022273, 14.51492954,
#        11.39131414, 14.24304857, 22.25748151, 18.34770869, 22.28738487,
#        18.76470919, 20.99815449, 20.56864904, 15.47518382, 23.44838001,
#        14.49793407, 11.70474034, 20.60656745, 23.52588229, 18.22696058,
#        17.38573596, 21.95961205, 24.962053  , 11.15701995, 15.93613218,
#        14.56957542, 21.58086384, 22.10377922, 21.63526014, 11.5060178 ,
#        21.65313878, 17.53728905, 12.28815189, 24.16059204, 21.61905698,
#        17.64680528, 24.74048707, 13.89248102, 12.6487094 , 18.28773783,
#        18.34658523, 10.3015443 , 24.86365686, 17.53371384, 11.31902621,
#        16.01285433, 14.49835042, 21.40079314, 20.09213444, 24.32081019,
#        20.40549234, 14.22406997, 23.98802288, 20.15220964, 18.54528975,
#        24.03374581, 22.86922891, 12.13420841, 10.45062325, 22.91289449,
# ...

# %%
random_numbers_plot(10,15,100)
# Out:
# /var/folders/hg/5fvxfx192g7d6pntmljmf7c00000gn/T/ipykernel_78685/254446751.py:9: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   return sns.histplot(random, palette="Blues");
# <Axes: ylabel='Count'>

# %%
random_numbers (10,60,1000)
# Out:
# array([20.18388266, 24.61346376, 28.89850026, 25.55276268, 68.26960869,
#        63.40963967, 62.58069585, 54.24668447, 16.15704914, 38.47130764,
#        35.86824267, 30.16646903, 37.76978857, 52.41261826, 25.46533621,
#        60.02144508, 30.2665273 , 24.46011586, 37.38177055, 12.14425949,
#        44.31993995, 59.35439536, 66.83021982, 65.52734638, 18.95098815,
#        65.75991066, 66.83592587, 62.1237181 , 27.78455366, 32.44523994,
#        32.56670081, 52.12369841, 59.64689289, 52.70749149, 26.46029916,
#        55.38056885, 47.65475688, 26.20510536, 67.97203602, 27.51252468,
#        59.78109837, 55.72440345, 24.82274333, 19.08477087, 29.28360631,
#        62.85997744, 49.21949355, 19.49013542, 65.66183977, 50.10338822,
#        69.92777935, 57.81602299, 65.90482163, 63.77470608, 50.00112982,
#        58.17374844, 53.12052372, 67.83867574, 62.95957381, 62.17358919,
#        57.95668565, 13.52142831, 34.42117546, 15.05940388, 46.35662205,
# ...

# %%
random_numbers_plot (10,60,1000)
# Out:
# /var/folders/hg/5fvxfx192g7d6pntmljmf7c00000gn/T/ipykernel_78685/254446751.py:9: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   return sns.histplot(random, palette="Blues");
# <Axes: ylabel='Count'>

# %% [markdown]
# How are the two distributions different?

# %%
# When the number of the count is higher, the values will tend to appear the same number of times. 
# So in the visualization we can see that the plot tend to be more plain between the values

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
def normal_distribution (average, stdev, sample):
    normal = norm(average, stdev)
    sample_of_normal = normal.rvs(sample)
    return sns.histplot(sample_of_normal)

# %%
normal_distribution (10, 1, 1000)
# Out:
# <Axes: ylabel='Count'>

# %%
normal_distribution (10, 50, 1000)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# How are the two distributions different?

# %%
# As the second sample has a higher standard deviation we can see that the values to the sides of the plot are much wider going from -150 until 150, having the same mean
# Stdev influentiates the probabilities of the numbers on right and left, meaning that in the second distribution numbers far away from the mean have higher probability than numbers from the first distribution.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
vehicles = pd.read_csv("vehicles.csv")
vehicles
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
avg = (vehicles["Fuel Barrels/Year"]).mean()
stdev = (vehicles["Fuel Barrels/Year"]).std()
sample = len(vehicles["Fuel Barrels/Year"])


fuel_barrel =normal_distribution (avg, stdev, sample)
fuel_barrel
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
avg = (vehicles["CO2 Emission Grams/Mile"]).mean()
stdev = (vehicles["CO2 Emission Grams/Mile"]).std()
sample = len(vehicles["CO2 Emission Grams/Mile"])


normal_distribution (avg, stdev, sample)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# 3. Combined MPG

# %%
avg = (vehicles["Combined MPG"]).mean()
stdev = (vehicles["Combined MPG"]).std()
sample = len(vehicles["Combined MPG"])


normal_distribution (avg, stdev, sample)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# The 3 functions seem to be normal distributited

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def exponential (mean, count):
    my_expon = expon(scale=mean)
    sns.histplot(my_expon.rvs(count)) # average is 30
    plt.axvline(mean, c="r");

# %%
exponential (200, 1000)

# %% [markdown]
# How are the two distributions different?

# %%
# Higher mean leads to a more spread out distribution

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)

mean = 10
minute = 15

prob_less_15_mins = expon.cdf(minute, scale = 10)
prob_less_15_mins
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
1 - prob_less_15_mins
# Out:
# 0.2231301601484298
