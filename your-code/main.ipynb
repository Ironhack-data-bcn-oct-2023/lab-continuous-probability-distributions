# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
from scipy.stats import norm
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
from scipy.stats import expon

x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.53834265 2.156868   2.24603016 2.83412836 2.31809702 2.66348858
#  2.35917113 2.98829211 2.20618877 2.63567191]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def uni_dist_rnd(bottom, ceiling, count):
    x = uniform.rvs(size=count)
    a = bottom
    b = ceiling
    random  = a + (b-a)*x
    return random

g1 = uni_dist_rnd(10,15,10)
g2 = uni_dist_rnd(10,60,1000)

fig, axes = plt.subplots(1, 2)
graph1 = sns.histplot(g1, palette="Blues", bins=10,ax=axes[0])
graph2= sns.histplot(g2, palette="Blues", bins=10,ax=axes[1])
graph1.set(ylim=(0,100))
graph2.set(ylim=(0,100))

plt.subplots_adjust(bottom=0.1, right=1.3, top=0.9)

plt.show()
# Out:
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_6086/1833294476.py:12: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   graph1 = sns.histplot(g1, palette="Blues", bins=10,ax=axes[0])
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_6086/1833294476.py:13: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   graph2= sns.histplot(g2, palette="Blues", bins=10,ax=axes[1])

# %% [markdown]
# How are the two distributions different?

# %%
# They are similar but as we are using different frequency , histograms shape seems different.
# If we generate a high level of numbers, histograms will tend to a flat line in the top.
# So they are different due to frequency.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
def rnd_norm_dist (n, mean, std):
    norm_dst = norm(mean, std)
    v_array = norm_dst.rvs(n)
    return v_array
    
set_norm1 = rnd_norm_dist(1000,10,1)
set_norm2 = rnd_norm_dist(1000,10,50)

fig, axes = plt.subplots(1, 2)
gr1 = sns.histplot(set_norm1, palette="Blues", bins=80,ax=axes[0])
gr2 = sns.histplot(set_norm2 ,palette="Blues", bins=80,ax=axes[1])
gr1.set(ylim=(0,60))
gr2.set(ylim=(0,60))

plt.subplots_adjust(bottom=0.1, right=1.3, top=0.9)

plt.show()
# Out:
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_6086/2767373095.py:10: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   gr1 = sns.histplot(set_norm1, palette="Blues", bins=80,ax=axes[0])
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_6086/2767373095.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   gr2 = sns.histplot(set_norm2 ,palette="Blues", bins=80,ax=axes[1])

# %% [markdown]
# How are the two distributions different?

# %%
# First set values are closest to mean, but the second set is more on the tails

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
df = pd.read_csv("../your-code/vehicles.csv")
df.sample(5)
# Out:
#                 Make                 Model  Year  Engine Displacement  \
# 24393  Mercedes-Benz                 SL500  2005                  5.0
# 1844             BMW                  330i  2004                  3.0
# 3134         Bentley        Continental GT  2015                  6.0
# 4976       Chevrolet               Caprice  1986                  4.3
# 9635           Dodge  D100/D150 Pickup 2WD  1993                  5.9
#
#        Cylinders     Transmission        Drivetrain           Vehicle Class  \
# 24393        8.0  Automatic 7-spd  Rear-Wheel Drive             Two Seaters
# 1844         6.0   Automatic (S5)  Rear-Wheel Drive            Compact Cars
# 3134        12.0   Automatic (S8)   All-Wheel Drive            Compact Cars
# 4976         6.0  Automatic 4-spd  Rear-Wheel Drive              Large Cars
# 9635         8.0  Automatic 4-spd  Rear-Wheel Drive  Standard Pickup Trucks
#
#             Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
plt.hist(df["Fuel Barrels/Year"], bins=50);
plt.xlabel("Fuel Barrels per Year")
plt.ylabel("Frequency")
plt.title("Number of Fuel barrels per year")
# Out:
# Text(0.5, 1.0, 'Number of Fuel barrels per year')

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
plt.hist(df["CO2 Emission Grams/Mile"], bins=50);
plt.xlabel("CO2 Emission Grams/Mile")
plt.ylabel("Count")
plt.title("CO2 Emission Grams/Mile")
# Out:
# Text(0.5, 1.0, 'CO2 Emission Grams/Mile')

# %% [markdown]
# 3. Combined MPG

# %%
plt.hist(df["Combined MPG"], bins=50);
plt.xlabel("Combined MPG")
plt.ylabel("Count")
plt.title("Combined MPG")
# Out:
# Text(0.5, 1.0, 'Combined MPG')

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# Fuel Barrels per year and CO2 emissions are normally distributed but Combined MPG is skewed to left so it mean positive.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def expo (lnum, size):
    x = np.random.exponential(lnum, size)
    return x

expo_1 = expo(2,1000)
expo_2 = expo(200,1000)

# %%
fig, axes = plt.subplots(1, 2)
ex1 = sns.histplot(expo_1, palette="Blues", bins=80,ax=axes[0])
ex2 = sns.histplot(expo_2 ,palette="Blues", bins=80,ax=axes[1])
ex1.set(ylim=(0,60))
ex2.set(ylim=(0,60))
plt.xlabel("Distribution")
plt.ylabel("Frequency")
plt.title("Exponential")
plt.subplots_adjust(bottom=0.1, right=1.3, top=0.9)

plt.show()
# Out:
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_6086/2483998104.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ex1 = sns.histplot(expo_1, palette="Blues", bins=80,ax=axes[0])
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_6086/2483998104.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ex2 = sns.histplot(expo_2 ,palette="Blues", bins=80,ax=axes[1])

# %% [markdown]
# How are the two distributions different?

# %%
# First set charted is decreasing faster than second one.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# Hint: This is same as saying P(x<15)

print(expon(10).cdf(15))
# Out:
# 0.9932620530009145

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
print(1 - expon(10).cdf(15))
# Out:
# 0.006737946999085476
