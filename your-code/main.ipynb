# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform
from scipy.stats import norm
import pandas as pd
from scipy.stats import expon

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.66568083 2.8865469  2.23372965 2.25678612 2.75910941 2.92975978
#  2.54003498 2.4968854  2.96979378 2.21870912]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def uniformly_numbers(bottom, ceiling, count):
    x = uniform.rvs(size=count)
    randoms = bottom + (ceiling - bottom) * x
    return randoms

uniformly1 = uniformly_numbers(10, 15, 100)
uniformly2 = uniformly_numbers(10, 60, 1000)

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.hist(uniformly1, bins=10, edgecolor='black', color='violet')
plt.title('Uniform Distribution 10-15-100')
plt.xlabel('Value')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
plt.hist(uniformly2, bins=10, edgecolor='black', color='lightblue')
plt.title('Uniform Distribution 10-60-1000')
plt.xlabel('Value')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
"""
The first distribution generates 100 random numbers between 10 and 15, which results in a narrower histogram—each bin represents a smaller range of values. It shows mopre variation in bin counts due to the smaller sample size.
The second distribution produces 1,000 random numbers between 10 and 60, creating a broader histogram where each bin encompasses a larger range of values. This one shows a smoother and more consistent spread of numbers across all the sections
"""
# Out:
# '\nThe first distribution generates 100 random numbers between 10 and 15, which results in a narrower histogram—each bin represents a smaller range of values. It shows mopre variation in bin counts due to the smaller sample size.\nThe second distribution produces 1,000 random numbers between 10 and 60, creating a broader histogram where each bin encompasses a larger range of values. This one shows a smoother and more consistent spread of numbers across all the sections\n'

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
def normal_numbers(mean, std_dev, count):
    return norm.rvs(loc=mean, scale=std_dev, size=count)

normal1 = normal_numbers(10, 1, 1000)
normal2 = normal_numbers(10, 50, 1000)

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.hist(normal1, bins=30, edgecolor='black', alpha=0.7, color='violet')
plt.title('Normal Distribution mean=10 std_dev=1)')
plt.xlabel('Value')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
plt.hist(normal2, bins=30, edgecolor='black', alpha=0.7, color='lightblue')
plt.title('Normal Distribution mean=10 std_dev=50')
plt.xlabel('Value')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
"""
The first set of numbers with a small standard deviation of 1 clusters tightly around the mean, resulting in a steep and narrow bell-shaped curve on the histogram—most numbers fall close to 10. 
The second second set, with a large standard deviation of 50, is much more spread out. This creates a shallower and wider bell-shaped curve, indicating that the numbers are more dispersed and many fall far from the average

"""
# Out:
# '\nThe first set of numbers with a small standard deviation of 1 clusters tightly around the mean, resulting in a steep and narrow bell-shaped curve on the histogram—most numbers fall close to 10. \nThe second second set, with a large standard deviation of 50, is much more spread out. This creates a shallower and wider bell-shaped curve, indicating that the numbers are more dispersed and many fall far from the average\n\n'

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
vehicles = pd.read_csv(r"C:\Users\photo\Desktop\Ironhack\labs\week-5\lab-continuous-probability-distributions\your-code\vehicles.csv", encoding='latin1')
vehicles
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
plt.figure(figsize=(10, 6))
plt.hist(vehicles['Fuel Barrels/Year'], bins=30, edgecolor='black', alpha=0.7, color="springgreen")
plt.title('Fuel Barrels per Year')
plt.xlabel('Fuel Barrels/Year')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
plt.figure(figsize=(10, 6))
plt.hist(vehicles['CO2 Emission Grams/Mile'], bins=30, edgecolor='black', alpha=0.7, color='yellow')
plt.title('CO2 Emission Grams/Mile')
plt.xlabel('CO2 Emission Grams per Mile')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
plt.figure(figsize=(10, 6))
plt.hist(vehicles['Combined MPG'], bins=30, edgecolor='black', color='mediumvioletred', alpha=0.7)
plt.title('Combined MPG')
plt.xlabel('Combined MPG')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
"""
The peak represents the most common value or range of values (the mean in a perfectly normal distribution), and the descending sides indicate that values farther from the mean are less frequent. 
In a perfectly normal distribution, the fall-off from the peak is symmetric.

"""
# Out:
# '\nThe peak represents the most common value or range of values (the mean in a perfectly normal distribution), and the descending sides indicate that values farther from the mean are less frequent. \nIn a perfectly normal distribution, the fall-off from the peak is symmetric.\n\n'

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def exponential_numbers(mean, size):
    scale = mean
    return np.random.exponential(scale, size)

exponential1 = exponential_numbers(2, 1000)
exponential2 = exponential_numbers(200, 1000)

plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
plt.hist(exponential1, bins=100, color='blue', alpha=0.7)
plt.title('Exponential Distribution (mean=2)')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(exponential2, bins=100, color='orange', alpha=0.7)
plt.title('Exponential Distribution (mean=200)')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
"""The first distribution, with a mean of 2, has a steep drop-off, meaning most of the values are concentrated close to zero and the frequency of higher values declines rapidly.
The second distribution, with a mean of 200, stretches out much farther along the value axis, with a slower decline in frequency. This results in a wider spread of values, so while we still see the characteristic rapid decrease in numbers as we move away from zero, the decline is stretched out over a larger range due to the higher mean. 
The greater the mean, the more spread out and the 'flatter' the exponential curve appears in the histogram.
"""
# Out:
# "The first distribution, with a mean of 2, has a steep drop-off, meaning most of the values are concentrated close to zero and the frequency of higher values declines rapidly.\nThe second distribution, with a mean of 200, stretches out much farther along the value axis, with a slower decline in frequency. This results in a wider spread of values, so while we still see the characteristic rapid decrease in numbers as we move away from zero, the decline is stretched out over a larger range due to the higher mean. \nThe greater the mean, the more spread out and the 'flatter' the exponential curve appears in the histogram.\n"

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
scale = 10  # mean = 10 minutes

prob_less15min = expon.cdf(15, scale=scale)
prob_less15min
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
prob_more15min = 1 - prob_less15min
prob_more15min
# Out:
# 0.2231301601484298
