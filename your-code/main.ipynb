# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.62431002 2.25205967 2.56418685 2.07736259 2.91242309 2.76983353
#  2.81101566 2.08149624 2.51064266 2.64979631]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def unif_random(bottom, ceiling, count):
    x = uniform.rvs(size=count)
    a = bottom
    b = ceiling
    randoms  = a + (b-a)*x
    return randoms

# %% [markdown]
# How are the two distributions different?

# %%
example_1 = unif_random(10, 15, 100)
example_1
# Out:
# array([14.28169976, 14.56533079, 13.87485927, 13.31704009, 11.85123717,
#        12.59084754, 13.85301028, 13.69463019, 10.6102107 , 10.04907147,
#        11.47416884, 13.63218263, 10.41684565, 12.69891342, 12.88224125,
#        13.84577926, 13.45910453, 11.13610276, 12.4134686 , 10.25008116,
#        12.75734552, 14.9073674 , 12.33873456, 13.19670705, 11.44495102,
#        12.69713634, 11.13682626, 10.12414934, 10.49728382, 12.70816741,
#        14.90280011, 14.21001073, 11.44120158, 14.13179082, 11.62755631,
#        10.66920926, 12.66593007, 13.88597874, 10.36380483, 10.17378145,
#        12.07219396, 11.254848  , 13.77381742, 14.51799585, 13.73500631,
#        14.46915455, 10.17374268, 13.32497656, 12.12988634, 12.66891147,
#        12.01607854, 11.2451731 , 13.49960739, 13.47339885, 14.42318447,
#        12.96419496, 11.43374586, 10.03846688, 10.47341006, 11.09219261,
#        10.80932532, 13.23974342, 12.06334944, 10.92917903, 10.63613658,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.histplot(data=example_1, bins=10, color="blue", kde=False)
plt.ylim(0, 120)
# Out:
# (0.0, 120.0)

# %%
example_2 = unif_random(10, 60, 1000)
example_2
# Out:
# array([59.81745748, 34.52595204, 42.28999504, 40.67731856, 57.00990434,
#        32.42421616, 13.14754757, 48.63976128, 18.31314782, 28.68880749,
#        10.06037835, 32.4154197 , 56.31589684, 22.21545285, 58.30274536,
#        23.19745172, 55.49873085, 47.63210238, 46.26576412, 42.07949727,
#        39.54855205, 40.42350918, 30.06493064, 46.54010036, 23.41944476,
#        47.66481921, 41.59817446, 17.20981657, 31.25707589, 24.34138965,
#        52.14102603, 14.64451958, 59.67438872, 33.08138484, 10.76028304,
#        20.27023604, 56.45167913, 47.54260261, 39.63006632, 55.986416  ,
#        11.74496075, 16.44484375, 20.92533725, 45.26381358, 12.79104445,
#        34.62213847, 34.7425596 , 19.88677294, 54.18739641, 42.06202344,
#        37.66939747, 52.73813768, 30.4251888 , 54.76130502, 41.94865518,
#        19.3376787 , 12.80149713, 59.74367572, 37.34731167, 37.66390671,
#        41.515579  , 59.79805623, 46.50270889, 15.21197912, 13.66815459,
# ...

# %%
sns.histplot(data=example_2, bins=10, color="blue", kde=False)
plt.ylim(0, 120)
# Out:
# (0.0, 120.0)

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %% [markdown]
# How are the two distributions different?

# %%
from scipy.stats import norm

# %%
def norm_random(mean, std_dev, count):
    x = norm.rvs(size=count)
    a = mean
    b = std_dev
    randoms  = a + (b-a)*x
    return randoms

# %%
example_3 = norm_random(10, 1, 1000)
example_3
# Out:
# array([ 1.72892692e+01,  1.76508015e+01,  2.26971167e+01,  6.36520469e+00,
#         1.47175403e+01,  9.54742430e+00,  1.32980559e+01,  1.11200991e+01,
#         5.37856525e+00,  2.34818660e+01,  1.50644892e+01,  1.78558638e+01,
#         1.42055217e+01,  7.84666604e+00,  1.06135589e+01,  1.16865740e+00,
#         2.26878515e+01,  8.09876282e+00, -1.79538627e+01,  2.14953490e+01,
#        -5.16879738e-01,  3.01407180e+01, -2.56740728e+00,  7.92111997e+00,
#         1.81890797e+01,  1.30449160e+01,  1.80970304e+01,  2.15265860e+01,
#        -4.76727003e+00, -1.06066515e+00,  7.00574272e+00,  2.01006023e+01,
#         8.03786825e+00, -9.13876437e-02,  1.26901633e+01,  2.59500992e+01,
#        -9.62276321e+00,  7.06958264e+00,  4.94165448e+00, -4.11991077e+00,
#         1.49102683e+01, -3.56304650e+00,  1.29504516e+01, -1.04073438e+01,
#         1.65484838e+01, -2.00648351e+00,  8.23509446e+00,  7.70731801e+00,
# ...

# %%
plt.figure(figsize=(4,6))
sns.histplot(data=example_3, bins=50, color="blue", kde=False)
plt.ylim(0, 70)
# Out:
# (0.0, 70.0)

# %%
example_4 = norm_random(10, 50, 1000)
example_4
# Out:
# array([ 2.09865790e+01,  5.91650802e+01, -2.16619711e+01,  2.82173999e+01,
#         5.55298756e+01,  6.13416389e+01, -1.87424063e+01,  5.36483809e+01,
#         2.65568410e+01,  1.41153952e+01,  3.72949337e+01,  4.11187308e+01,
#         4.89230027e+01,  4.07293326e+01,  8.24870163e+01,  7.38878094e+01,
#         8.80510415e+01,  1.84663230e+01,  1.53343600e+01,  1.05446369e+00,
#         5.43238763e+01,  1.39907649e+01, -3.09002345e+01,  3.15068967e+01,
#         8.18511204e+01,  7.88828048e+01,  3.53187993e+01,  2.20776530e+00,
#         6.44220018e+01,  5.79172874e+00, -9.74046228e+01,  1.35162786e+01,
#        -2.46600778e+00,  2.35369648e+01,  8.44712641e+01,  3.67758528e+01,
#        -5.15742265e+01,  1.71637178e+01,  6.65793204e+01,  2.11981713e+01,
#        -4.21823145e+01,  5.81781029e+01,  2.71672882e+01, -4.20707953e+01,
#        -2.15387384e+01,  2.31720092e+00,  4.88707945e+01,  5.66026930e+01,
# ...

# %%
plt.figure(figsize=(4,6))
sns.histplot(data=example_4, bins=50, color="blue", kde=False)
plt.ylim(0, 70)
# Out:
# (0.0, 70.0)

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
vehicles = pd.read_csv('vehicles.csv')
vehicles
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
plt.hist(vehicles['Fuel Barrels/Year'], bins=80, color='blue', edgecolor='black')
plt.xlabel('Fuel Barrels/Year')
plt.ylabel('Count')
plt.title('Normal Distribution of Fuel Barrels/Year')
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
plt.hist(vehicles['CO2 Emission Grams/Mile'], bins=80, color='blue', edgecolor='black')
plt.xlabel('CO2 Emission Grams/Mile')
plt.ylabel('Count')
plt.title('Normal Distribution of CO2 Emission Grams/Mile')
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
plt.hist(vehicles['Combined MPG'], bins=80, color='blue', edgecolor='black')
plt.xlabel('Combined MPG')
plt.ylabel('Count')
plt.title('Normal Distribution of Combined MPG')
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# 'Fuel Barrels/Year' and  'CO2 Emission Grams/Mile' are nearly normally distributed because they have a bell shape. However, the 'Combined MPG' is not because it is skewed to the right.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
import numpy as np

# %%
def exp_distr(mean, size):
    numbers = np.random.exponential(mean, size)
    return numbers

# %%
exp_distr_2 = exp_distr(2, 1000)

# %%
exp_distr_200 = exp_distr(200, 1000)

# %%
plt.hist(exp_distr_2, bins=100, color='blue', edgecolor='black')
plt.show()

# %%
plt.hist(exp_distr_200, bins=100, color='blue', edgecolor='black')
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# The range of the X-axis is higher in the second plot because the mean considered to calculate is higher.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
from scipy.stats import expon

# %%
my_expon = expon(scale=10)
my_expon.cdf(15)
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
1 - my_expon.cdf(16)
# Out:
# 0.2231301601484298
