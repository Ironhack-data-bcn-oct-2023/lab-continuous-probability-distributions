# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
from scipy.stats import bernoulli
from scipy.stats import binom
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.91434125 2.12394523 2.77018469 2.42288903 2.10396909 2.27109661
#  2.85920188 2.38928668 2.35625113 2.99471334]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def uniformly_distributed_random(bottom, ceiling, count):
    x = uniform.rvs(size=count)
    array = bottom + (ceiling - bottom)*x
    return array

# %%
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# %%
hist_1 = uniformly_distributed_random(10, 15, 100)

# %%
sns.histplot(hist_1, palette="Blues", bins = 10)
# Out:
# /var/folders/q9/jkycd7cd6tqdf410bnlz4q2c0000gn/T/ipykernel_26674/2684414162.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(hist_1, palette="Blues", bins = 10)
# <Axes: ylabel='Count'>

# %%
hist_2 = uniformly_distributed_random(10, 60, 1000)

# %%
sns.histplot(hist_2, palette="Blues", bins = 10)
# Out:
# /var/folders/q9/jkycd7cd6tqdf410bnlz4q2c0000gn/T/ipykernel_26674/2823654000.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(hist_2, palette="Blues", bins = 10)
# <Axes: ylabel='Count'>

# %% [markdown]
# How are the two distributions different?

# %%
#The second one is more consistent (less variety) due to the dataset being much larger.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
def normally_distributed_random(mean, std_dev, count):
    x = np.random.normal(mean, std_dev, count)
    return x

# %%
normal_1 = normally_distributed_random(10, 1, 1000)

# %%
normal_2 = normally_distributed_random(10, 50, 1000)

# %%
sns.histplot(normal_1, palette="Blues", bins = 10)
# Out:
# /var/folders/q9/jkycd7cd6tqdf410bnlz4q2c0000gn/T/ipykernel_26674/2669310892.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(normal_1, palette="Blues", bins = 10)
# <Axes: ylabel='Count'>

# %%
sns.histplot(normal_2, palette="Blues", bins = 10)
# Out:
# /var/folders/q9/jkycd7cd6tqdf410bnlz4q2c0000gn/T/ipykernel_26674/1399300940.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(normal_2, palette="Blues", bins = 10)
# <Axes: ylabel='Count'>

# %% [markdown]
# How are the two distributions different?

# %%
#1 is more 'normally' distributed due to having a lower standard deviation

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
data = pd.read_csv("vehicles.csv")
data
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
sns.histplot(data["Fuel Barrels/Year"], palette="Blues", bins = 20)
# Out:
# /var/folders/q9/jkycd7cd6tqdf410bnlz4q2c0000gn/T/ipykernel_26674/40483205.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data["Fuel Barrels/Year"], palette="Blues", bins = 20)
# <Axes: xlabel='Fuel Barrels/Year', ylabel='Count'>

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
sns.histplot(data["CO2 Emission Grams/Mile"], palette="Blues", bins = 20)
# Out:
# /var/folders/q9/jkycd7cd6tqdf410bnlz4q2c0000gn/T/ipykernel_26674/1937776638.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data["CO2 Emission Grams/Mile"], palette="Blues", bins = 20)
# <Axes: xlabel='CO2 Emission Grams/Mile', ylabel='Count'>

# %% [markdown]
# 3. Combined MPG

# %%
sns.histplot(data["Combined MPG"], palette="Blues", bins = 20)
# Out:
# /var/folders/q9/jkycd7cd6tqdf410bnlz4q2c0000gn/T/ipykernel_26674/1376326078.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data["Combined MPG"], palette="Blues", bins = 20)
# <Axes: xlabel='Combined MPG', ylabel='Count'>

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
#All of them are normally distributed, even though some are positively and negatively skewed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def exponentially_distributed_random(mean, count):
    x = np.random.exponential(mean, count)
    return x

# %%
expo_1 = exponentially_distributed_random(2, 1000)

# %%
expo_2 = exponentially_distributed_random(200, 1000)

# %%
sns.histplot(expo_1, palette="Blues", bins = 100)
# Out:
# /var/folders/q9/jkycd7cd6tqdf410bnlz4q2c0000gn/T/ipykernel_26674/1026873897.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(expo_1, palette="Blues", bins = 100)
# <Axes: ylabel='Count'>

# %%
sns.histplot(expo_2, palette="Blues", bins = 100)
# Out:
# /var/folders/q9/jkycd7cd6tqdf410bnlz4q2c0000gn/T/ipykernel_26674/3632025633.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(expo_2, palette="Blues", bins = 100)
# <Axes: ylabel='Count'>

# %% [markdown]
# How are the two distributions different?

# %%
#The second one is more spread out towards the right of the x axis, and the curve is less steep. 
#This means it is not as exponentially distributed as the first 1. 
#I am not sure what explains this given they are both the same size (1000)

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
x = np.random.exponential(10)
# Out:
# 6.493242854047809

# %%
rate_parameter = 1/10

x = 15

probability_15 = 1 - np.exp(-rate_parameter * x)
probability_15
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
probability_more_15 = np.exp(-rate_parameter * x)
probability_more_15
# Out:
# 0.22313016014842982
