# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %%
import numpy as np
from scipy.stats import uniform, norm, expon
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.35487887 2.82559089 2.22093722 2.26995537 2.70271184 2.00834924
#  2.73578362 2.64297084 2.13623004 2.18556777]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def uniform_dist(bottom, ceiling, count):
    range_ = ceiling-bottom
    dist_uni = uniform(bottom, range_)
    return dist_uni.rvs(count)

# %%
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize': (8, 4)})
fig,axs = plt.subplots(1,2)
# bottom=10, ceiling=15, count=100
bottom = 10
ceiling = 15
count = 100
arrayI = uniform_dist(bottom, ceiling, count)
I = sns.histplot(arrayI, bins = 10, ax = axs[0])
I.set(ylim = (0, 110))

ceiling = 60
count = 1000
arrayII = uniform_dist(bottom, ceiling, count)
II = sns.histplot(arrayII, bins = 10, ax = axs[1])
II.set(ylim = (0, 110));

# %% [markdown]
# How are the two distributions different?

# %%
'''
The first one goes from 10 to 15, the sum of all counts is 100. The distribution seems homogeneous, although some ups and downs
can be seen.
The second one goes from 10 to 60, the sum of all counts is 1000. The distribution appears more homogeneous because of the amount
of counts.
'''

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
def normal_dist(avg, st, count):
    dist_norm = norm(avg, st)
    return dist_norm.rvs(count)
fig,axs = plt.subplots(1,2)
# Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
avg =  10
st = 1
count = 1000
arrayI = normal_dist(avg, st, count)
I = sns.histplot(arrayI, bins = 45, ax = axs[0])
I.set(ylim = (0, 65))
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
avg =  10
st = 50
count = 1000
arrayII = normal_dist(avg, st, count)
II = sns.histplot(arrayII, bins = 45, ax = axs[1])
II.set(ylim = (0, 65));

# %% [markdown]
# How are the two distributions different?

# %%
'''
The first one has a smaller width. If they showed the same proportions in the x axis, we would see that the second graph is much
more flat.
'''

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
df = pd.read_csv("vehicles.csv")
df.sample()
# Out:
#            Make           Model  Year  Engine Displacement  Cylinders  \
# 6846  Chevrolet  S10 Pickup 2WD  1990                  2.5        4.0
#
#       Transmission        Drivetrain        Vehicle Class Fuel Type  \
# 6846  Manual 5-spd  Rear-Wheel Drive  Small Pickup Trucks   Regular
#
#       Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 6846          14.982273        21           25            22
#
#       CO2 Emission Grams/Mile  Fuel Cost/Year
# 6846               403.954545            1500

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
sns.histplot(df, x= "Fuel Barrels/Year", bins = 50)
plt.axvline(x=df["Fuel Barrels/Year"].mean(), color = "r")
plt.axvline(x=(df["Fuel Barrels/Year"].mean() - df["Fuel Barrels/Year"].std()), color = "y", linestyle = "--")
plt.axvline(x=(df["Fuel Barrels/Year"].mean() + df["Fuel Barrels/Year"].std()), color = "y", linestyle = "--")
plt.axvline(x=(df["Fuel Barrels/Year"].mean() - 2 * df["Fuel Barrels/Year"].std()), color = "g", linestyle = ":")
plt.axvline(x=(df["Fuel Barrels/Year"].mean() + 2 * df["Fuel Barrels/Year"].std()), color = "g", linestyle = ":");

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
sns.histplot(df, x= "CO2 Emission Grams/Mile", bins = 50);
plt.axvline(x=df["CO2 Emission Grams/Mile"].mean(), color = "r")
plt.axvline(x=(df["CO2 Emission Grams/Mile"].mean() - df["CO2 Emission Grams/Mile"].std()), color = "y", linestyle = "--")
plt.axvline(x=(df["CO2 Emission Grams/Mile"].mean() + df["CO2 Emission Grams/Mile"].std()), color = "y", linestyle = "--")
plt.axvline(x=(df["CO2 Emission Grams/Mile"].mean() - 2 * df["CO2 Emission Grams/Mile"].std()), color = "g", linestyle = ":")
plt.axvline(x=(df["CO2 Emission Grams/Mile"].mean() + 2 * df["CO2 Emission Grams/Mile"].std()), color = "g", linestyle = ":");

# %% [markdown]
# 3. Combined MPG

# %%
sns.histplot(df, x= "Combined MPG", bins = 50);
plt.axvline(x=df["Combined MPG"].mean(), color = "r")
plt.axvline(x=(df["Combined MPG"].mean() - df["Combined MPG"].std()), color = "y", linestyle = "--")
plt.axvline(x=(df["Combined MPG"].mean() + df["Combined MPG"].std()), color = "y", linestyle = "--")
plt.axvline(x=(df["Combined MPG"].mean() - 2 * df["Combined MPG"].std()), color = "g", linestyle = ":")
plt.axvline(x=(df["Combined MPG"].mean() + 2 * df["Combined MPG"].std()), color = "g", linestyle = ":");

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
'''
The Combined MPG appears to be the most normal. It seems symetric from left to right of the mean (not much skewness).
We could check if the amount of data between mean +/- one standard deviation contains the 68.27% of the total data of this
variable.
We could also calculate the skewness of each distribution. But by looking at the graphs the normales distributions appears to be
the last one.
'''

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def exp_dist(scale, count):
    return np.random.exponential(scale, count)

# %%
exp_I= exp_dist(2, 1000)
exp_II= exp_dist(200, 1000)
fig,axs = plt.subplots(1,2)
I = sns.histplot(exp_I, bins = 100, ax = axs[0])
I.set(ylim = (0, 75))
II = sns.histplot(exp_II, bins = 100, ax = axs[1])
II.set(ylim = (0, 75));

# %% [markdown]
# How are the two distributions different?

# %%
'''The second one is much wider, because the mean is much bigger'''

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
banck = expon(scale=10)
banck.cdf(14)
# Out:
# 0.7534030360583935

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
1 - banck.cdf(14)
# Out:
# 0.24659696394160646
