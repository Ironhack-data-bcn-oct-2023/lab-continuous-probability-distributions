# %%
from matplotlib import pyplot as plt
from scipy.stats import norm
import numpy as np
import pandas as pd

# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.89006442 2.67676511 2.01369162 2.31378106 2.39771197 2.09272045
#  2.46345983 2.65244122 2.34001939 2.10933871]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def generates_uniformly_distributed_random_numbers(a, b, size):
    x = uniform.rvs(size=size)
    a = a
    b = b
    randoms  = a + (b-a)*x
    return randoms

minor_list = generates_uniformly_distributed_random_numbers(10,15,100)
big_list = generates_uniformly_distributed_random_numbers(10,60,1000)

# %%
plt.hist(minor_list, alpha=0.7)
plt.ylim(0, 25)
# Out:
# (0.0, 25.0)

# %%
# your code here
plt.hist(big_list, alpha=0.7)
plt.ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
def generates_normally_distributed_random_numbers(mean, std_dev, size):
    return np.random.normal(mean, std_dev, size)

deviation_1 = generates_normally_distributed_random_numbers(10, 1,1000)
deviation_50 = generates_normally_distributed_random_numbers(10, 50, 1000)

# %%
plt.hist(deviation_1)
plt.ylim(0, 250)
# Out:
# (0.0, 250.0)

# %%
plt.hist(deviation_50)
plt.ylim(0, 250)
# Out:
# (0.0, 250.0)

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# the second one have a bigger range of values? but in the plot, without the numbers they look very similar

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
vehicles = pd.read_csv("../your-code/vehicles.csv")
vehicles.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
sns.histplot(x = vehicles["Fuel Barrels/Year"])
# Out:
# <Axes: xlabel='Fuel Barrels/Year', ylabel='Count'>

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
sns.histplot(x = vehicles["CO2 Emission Grams/Mile"])
# Out:
# <Axes: xlabel='CO2 Emission Grams/Mile', ylabel='Count'>

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
sns.histplot(x = vehicles["Combined MPG"])
# Out:
# <Axes: xlabel='Combined MPG', ylabel='Count'>

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# Is there a easy way to find? ahahah
# I'm looking for the one more with more symmetri and think is the Combined MPG
# But not sure

# %%
# your answer here
''' 
In histograms, a nearly normal distribution often appears 
as a bell-shaped curve. The values are concentrated in the 
center and taper off towards the extremes. If you have a 
symmetric histogram where the majority of the data points 
cluster around the mean, it's an indication of a nearly 
normal distribution. '''
# Out:
# " \nIn histograms, a nearly normal distribution often appears \nas a bell-shaped curve. The values are concentrated in the \ncenter and taper off towards the extremes. If you have a \nsymmetric histogram where the majority of the data points \ncluster around the mean, it's an indication of a nearly \nnormal distribution. "

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here

def generates_exponential_distributed_random_numbers(scale, size):
    return np.random.exponential(scale, size)

mean_2 = generates_exponential_distributed_random_numbers(2, 1000)
mean_200 = generates_exponential_distributed_random_numbers(200, 1000)

# %%
plt.hist(mean_2)
# Out:
# (array([548., 253.,  97.,  54.,  26.,  10.,   5.,   4.,   2.,   1.]),
#  array([1.75287447e-04, 1.50449864e+00, 3.00882200e+00, 4.51314535e+00,
#         6.01746871e+00, 7.52179206e+00, 9.02611542e+00, 1.05304388e+01,
#         1.20347621e+01, 1.35390855e+01, 1.50434088e+01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mean_200)
# Out:
# (array([558., 248., 105.,  48.,  21.,  11.,   3.,   2.,   2.,   2.]),
#  array([2.71043358e-01, 1.57740061e+02, 3.15209078e+02, 4.72678096e+02,
#         6.30147113e+02, 7.87616131e+02, 9.45085148e+02, 1.10255417e+03,
#         1.26002318e+03, 1.41749220e+03, 1.57496122e+03]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here

# the change is on the x axis

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
from scipy.stats import expon

# %%
# your answer here
# Hint: This is same as saying P(x<15)
scale = 10 
my_expon = expon(scale)

less_15 = my_expon.cdf(15)
less_15
# Out:
# 0.9932620530009145

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
1 - less_15
# Out:
# 0.006737946999085476
