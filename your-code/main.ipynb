# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.82882214 2.85046532 2.73804526 2.61387531 2.21845923 2.58107984
#  2.15275796 2.6104524  2.69399813 2.98210215]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
#1.
def random_uniform_generator(bottom, ceiling, count):
    x = uniform.rvs(size=count)
    a = bottom
    b = ceiling
    randoms  = a + (b-a)*x
    return randoms

# %%
#2. 
unif_dist1 = random_uniform_generator(10, 15, 100)
unif_dist1
# Out:
# array([12.73483832, 11.59437981, 14.72765232, 10.32197745, 11.79797237,
#        12.6000436 , 11.29972532, 12.6309176 , 12.49043207, 11.67899895,
#        13.61987895, 13.01269233, 10.55198977, 11.7999007 , 14.8321434 ,
#        12.30334991, 11.71292968, 14.31800668, 10.96203571, 14.6694557 ,
#        10.95111886, 13.40028797, 11.12372331, 14.40658277, 12.71104312,
#        12.38949636, 11.97667203, 10.65044632, 12.18355501, 14.63409517,
#        10.66971137, 11.65377869, 11.5855131 , 12.48143637, 14.57633634,
#        12.65706187, 13.88969239, 10.00846264, 11.29945737, 10.95108518,
#        11.04166677, 10.40604881, 11.38040792, 10.23548979, 12.48872807,
#        10.63448562, 13.70320113, 11.39885332, 10.64448682, 12.73425706,
#        11.11745042, 10.66922765, 11.4559471 , 13.0845525 , 12.97306238,
#        14.51948744, 12.81507685, 14.70299407, 12.49190445, 14.39446395,
#        13.22848957, 14.55893941, 11.75297716, 11.60504776, 12.22480143,
# ...

# %%
unif_dist2 = random_uniform_generator(10, 60, 1000)
#unif_dist2

# %%
import seaborn as sns
import matplotlib as plt

# %%
import matplotlib.pyplot as plt
 
plt.hist(unif_dist1, bins=10, edgecolor='black')
plt.xlabel('values')
plt.ylabel('values count')
plt.show()

# %%
plt.hist(unif_dist2, bins=10, edgecolor='black')
plt.xlabel('values')
plt.ylabel('values count')
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
print("the ceiling and the count changes increasing from 15 -->60 and from 100-1000 respectively from dist1 to dist2. With larger amounts of data we would expect flatter distributions even though the range for the values to change also increases")
# Out:
# the ceiling and the count changes increasing from 15 -->60 and from 100-1000 respectively from dist1 to dist2. With larger amounts of data we would expect flatter distributions even though the range for the values to change also increases

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm
def random_normal_generator2(average, stddev, count):
    x = norm(average, stddev).rvs(size=count)
    return x

# %%
normal_3 = random_normal_generator2(10, 1,1000)

# %%
plt.hist(normal_3, bins=10, edgecolor='black')
plt.xlabel('values')
plt.ylabel('values count')
plt.show()

# %%
normal_4 = random_normal_generator2(10, 50,1000)

# %%
plt.hist(normal_4, bins=10, edgecolor='black')
plt.xlabel('values')
plt.ylabel('values count')
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
print("since the standard deviation is bigger in the second one, the distribution is less centered around the mean because we have a higher dispersion of values in the series")
# Out:
# since the standard deviation is bigger in the second one, the distribution is less centered around the mean because we have a higher dispersion of values in the series

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
import pandas as pd

# %%
vehicles = pd.read_csv("vehicles.csv")
vehicles.sample(3)
# Out:
#             Make           Model  Year  Engine Displacement  Cylinders  \
# 26328     Nissan      Armada 4WD  2015                  5.6        8.0
# 2908         BMW    X5 xDrive40e  2017                  2.0        4.0
# 6924   Chevrolet  S10 Pickup 4WD  1994                  4.3        6.0
#
#           Transmission                  Drivetrain  \
# 26328  Automatic 5-spd               4-Wheel Drive
# 2908    Automatic (S8)             All-Wheel Drive
# 6924      Manual 5-spd  4-Wheel or All-Wheel Drive
#
#                             Vehicle Class                Fuel Type  \
# 26328  Standard Sport Utility Vehicle 4WD          Gasoline or E85
# 2908   Standard Sport Utility Vehicle 4WD  Premium and Electricity
# 6924               Standard Pickup Trucks                  Premium
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 26328          23.543571        12           18            14
# 2908            9.179989        23           25            24
# ...

# %%
vehicles.hist(column='Fuel Barrels/Year')
# Out:
# array([[<Axes: title={'center': 'Fuel Barrels/Year'}>]], dtype=object)

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
vehicles.hist(column='CO2 Emission Grams/Mile')
# Out:
# array([[<Axes: title={'center': 'CO2 Emission Grams/Mile'}>]],
#       dtype=object)

# %% [markdown]
# 3. Combined MPG

# %%
vehicles.hist(column='Combined MPG')
# Out:
# array([[<Axes: title={'center': 'Combined MPG'}>]], dtype=object)

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
print("visually the one that looks like a bell shaped distribution the most is combined MPG. [from the internet] we can also perform a Shapiro-wilk test")

from scipy.stats import shapiro 
from scipy.stats import lognorm

fuel_barrels_year = vehicles['Fuel Barrels/Year'].to_numpy()
print(f"Shapiro-wilk test for combined_mpg is {shapiro(fuel_barrels_year)}")

co2_emission_grams_mile = vehicles['CO2 Emission Grams/Mile'].to_numpy()
print(f"Shapiro-wilk test for combined_mpg is {shapiro(co2_emission_grams_mile)}")

Combined_mpg = vehicles['Combined MPG'].to_numpy()
print(f"Shapiro-wilk test for combined_mpg is {shapiro(Combined_mpg)}")

print("well, shit, none of them reproduce a pvalue higher or even closer to 0.05, to be >0.5 would mean it's normally distributed.")
# Out:
# visually the one that looks like a bell shaped distribution the most is combined MPG. [from the internet] we can also perform a Shapiro-wilk test
# Shapiro-wilk test for combined_mpg is ShapiroResult(statistic=0.967258095741272, pvalue=0.0)
# Shapiro-wilk test for combined_mpg is ShapiroResult(statistic=0.9675898551940918, pvalue=0.0)
# Shapiro-wilk test for combined_mpg is ShapiroResult(statistic=0.9466004967689514, pvalue=0.0)
# well, shit, none of them reproduce a pvalue higher or even closer to 0.05, to be >0.5 would mean it's normally distributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
from scipy.stats import expon
def create_exponential(mean, size=100):
    list_exps = expon.rvs(scale=mean, size=size)
    return list_exps

exponential2 = create_exponential(2,1000)

# Plotting histogram
plt.hist(exponential2, bins=10, edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Values Count')
plt.show()

# %%
exponential2 = create_exponential(200,1000)

# Plotting histogram
plt.hist(exponential2, bins=10, edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Values Count')
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
print("the mean being higher translates into a 'thicker' distribution where it moves gradually to the infinite values at a lower pace")
# Out:
# the mean being higher translates into a 'thicker' distribution where it moves gradually to the infinite values at a lower pace

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
exponential_bank = create_exponential(10,1000)

# %%
from scipy.stats import expon

exponential_bank = create_exponential(10, 1000)
prob_waiting_less_than_15 = expon.cdf(15, scale=10)
print(f'prob_waiting_less_than_15 is: {prob_waiting_less_than_15}')
# Out:
# prob_waiting_less_than_15 is: 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
#simply the reverse:
prob_waiting_more_than_15 = 1 - prob_waiting_less_than_15
print(f'Cumulative Probability until 15: {prob_waiting_more_than_15}')
# Out:
# Cumulative Probability until 15: 0.2231301601484298
