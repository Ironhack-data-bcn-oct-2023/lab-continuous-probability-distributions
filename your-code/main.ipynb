# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.stats import norm
import pandas as pd
from scipy.stats import expon

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.66600686 2.74522993 2.999538   2.89955302 2.81907905 2.62099698
#  2.12007806 2.49335705 2.66047762 2.12764664]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def my_function(bottom,ceiling,count):
    x = uniform.rvs(size=count)
    a = bottom
    b = ceiling
    randoms  = a + (b-a)*x
    return randoms

# %%
#bottom=10, ceiling=15, count=100
count_100 = my_function(10,15,100)
plt.figure(figsize=(5, 3))
sns.histplot(count_100,bins=10);

# %%
#bottom=10, ceiling=60, count=1,000
count_1000 = my_function(10,60,1000)
plt.figure(figsize=(5, 3))
sns.histplot(count_1000,bins=10);

# %% [markdown]
# How are the two distributions different?

# %%
'''
the lower the number of 'count'(numbers generated randomly in the interval defined in the function between ceiling and 
bottom) the less uniform the distribution is. The higher the numbers generated then the closer the graph gets to the 
one corresponding to a uniform continous distribution.
'''

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
def uniform_distributed(qty_numb, mean, stdev):
    shape = norm(mean, stdev)
    array = shape.rvs(qty_numb)
    return array

# %%
#Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
stdev_1 = uniform_distributed(1000, 10, 1)
plt.figure(figsize=(4, 4))
sns.histplot(stdev_1,bins =100);

# %%
#Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
stdev_50 = uniform_distributed(1000, 10, 50)
plt.figure(figsize=(4, 4))
sns.histplot(stdev_50,bins =100);

# %% [markdown]
# How are the two distributions different?

# %%
'''
Although both distributions look similar the key point is the x axis values: it is far broader the one with std deviation
of 50. Both follow Gauss bell distribution.
'''

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
cars = pd.read_csv("vehicles.csv")
cars.sample()
# Out:
#      Make Model  Year  Engine Displacement  Cylinders     Transmission  \
# 660  Audi    A4  1997                  2.8        6.0  Automatic 5-spd
#
#             Drivetrain Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 660  Front-Wheel Drive  Compact Cars   Premium          17.347895        16
#
#      Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 660           26            19               467.736842            2150

# %%
plt.figure(figsize=(8,3))
plot = sns.histplot(cars['Fuel Barrels/Year'])

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
plt.figure(figsize=(8,3))
plot = sns.histplot(cars['CO2 Emission Grams/Mile'])

# %% [markdown]
# 3. Combined MPG

# %%
plt.figure(figsize=(8,3))
plot = sns.histplot(cars['Combined MPG'])

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# Combined MPG, it is the one that shows aprox a Gauss bell distribution.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def exp_function (qty_numb, mu):
    my_expon = expon(scale=mu ).rvs(qty_numb)
    return my_expon

# %%
exp_mu_2 = exp_function (1000, 2)

# %%
plt.figure(figsize = (8,3))
sns.histplot(exp_mu_2, bins = 100 )
# Out:
# <Axes: ylabel='Count'>

# %%
exp_mu_200 = exp_function (1000, 200)

# %%
plt.figure(figsize = (8,3))
sns.histplot(exp_mu_200, bins = 100 )
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# How are the two distributions different?

# %%
'''once again the difference is clear when looking at the x values: the function with mu=200 ploted have x values
10 times bigger than those generated when mu =2. So, the increase in the sample space is directly related to the 
increase in mu'''

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
my_exp = expon(scale = 10)
pr = my_exp.cdf(15)
 
print (f"probability will be less than {probability_less_than_15} but cannot get an exact number as time is coninuos")
# Out:
# probability will be less than 0.7768698398515702 but cannot get an exact number as time is coninuos

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
more_than_15 = 1-pr
more_than_15
# Out:
# 0.2231301601484298
